# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/train.csv', index_col=0)

# %%
data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
data_1 = data[['LotArea', 'FullBath', 'BedroomAbvGr', 'SalePrice']]

# %%
data_1
# Out:
#       LotArea  FullBath  BedroomAbvGr  SalePrice
# Id
# 1        8450         2             3     208500
# 2        9600         2             3     181500
# 3       11250         2             3     223500
# 4        9550         1             3     140000
# 5       14260         2             4     250000
# ...       ...       ...           ...        ...
# 1456     7917         2             3     175000
# 1457    13175         2             3     210000
# 1458     9042         2             4     266500
# 1459     9717         1             2     142125
# 1460     9937         1             3     147500
#
# [1460 rows x 4 columns]

# %%
data_1.isna().sum()
# Out:
# LotArea         0
# FullBath        0
# BedroomAbvGr    0
# SalePrice       0
# dtype: int64

# %%
data_1['area_norm'] = (data_1['LotArea'] - data_1['LotArea'].min()) / (data_1['LotArea'].max() - data_1['LotArea'].min())
# Out:
# C:\Users\noran\AppData\Local\Temp\ipykernel_18832\3430641843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_1['area_norm'] = (data_1['LotArea'] - data_1['LotArea'].min()) / (data_1['LotArea'].max() - data_1['LotArea'].min())

# %%
X = data_1.drop(['SalePrice', 'LotArea'], axis=1)
y = data_1['SalePrice']

# %%
X
# Out:
#       FullBath  BedroomAbvGr  area_norm
# Id
# 1            2             3   0.033420
# 2            2             3   0.038795
# 3            2             3   0.046507
# 4            1             3   0.038561
# 5            2             4   0.060576
# ...        ...           ...        ...
# 1456         2             3   0.030929
# 1457         2             3   0.055505
# 1458         2             4   0.036187
# 1459         1             2   0.039342
# 1460         1             3   0.040370
#
# [1460 rows x 3 columns]

# %%
y
# Out:
# Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
#          ...
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
test = pd.read_csv('data/test.csv', index_col=0)

# %%
test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# Id                                    ...
# 1461         Lvl    AllPub    Inside  ...         120        0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner  ...           0        0    NaN    NaN
# 1463         Lvl    AllPub    Inside  ...           0        0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside  ...           0        0    NaN    NaN
# 1465         HLS    AllPub    Inside  ...         144        0    NaN    NaN
#
# ...

# %%
data_2 = data[['LotArea', 'FullBath', 'BedroomAbvGr', 'SalePrice']]

# %%
data_2
# Out:
#       LotArea  FullBath  BedroomAbvGr  SalePrice
# Id
# 1        8450         2             3     208500
# 2        9600         2             3     181500
# 3       11250         2             3     223500
# 4        9550         1             3     140000
# 5       14260         2             4     250000
# ...       ...       ...           ...        ...
# 1456     7917         2             3     175000
# 1457    13175         2             3     210000
# 1458     9042         2             4     266500
# 1459     9717         1             2     142125
# 1460     9937         1             3     147500
#
# [1460 rows x 4 columns]

# %%
data_2.isna().sum()
# Out:
# LotArea         0
# FullBath        0
# BedroomAbvGr    0
# SalePrice       0
# dtype: int64

# %%
data_2['area_norm'] = (data_2['LotArea'] - data_2['LotArea'].min()) / (data_2['LotArea'].max() - data_2['LotArea'].min())
# Out:
# C:\Users\noran\AppData\Local\Temp\ipykernel_18832\3551288419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['area_norm'] = (data_2['LotArea'] - data_2['LotArea'].min()) / (data_2['LotArea'].max() - data_2['LotArea'].min())

# %%
X_test = data_2.drop(['SalePrice', 'LotArea'], axis=1)
y_test = data_2['SalePrice']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')
# Out:
# Mean Squared Error: 4066873836.62
# R-squared: 0.36
